# %%
#import dependencies
# %matplotlib inline
from IPython.display import Image, HTML
import json
import datetime
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier, XGBRegressor
from wordcloud import WordCloud, STOPWORDS
import plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
warnings.filterwarnings('ignore')


sns.set_style('whitegrid')
sns.set(font_scale=1.25)
pd.set_option('display.max_colwidth', 50)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Data Cleaning

# %%
#import data and create df
df = pd.read_csv('movies.csv')
df.head().T
# Out:
#                                                                       0  \
# id                                                               505642
# title                                    Black Panther: Wakanda Forever
# genres                                 Action-Adventure-Science Fiction
# original_language                                                    en
# overview              Queen Ramonda Shuri M’Baku Okoye and the Dora ...
# popularity                                                     3952.862
# production_companies                                     Marvel Studios
# release_date                                                 2022-11-09
# budget                                                      250000000.0
# revenue                                                     855099029.0
# runtime                                                           162.0
# status                                                         Released
# tagline                                                        Forever.
# vote_average                                                      7.403
# vote_count                                                       3586.0
# credits               Letitia Wright-Lupita Nyong'o-Danai Gurira-Win...
# keywords              loss of loved one-hero-sequel-superhero-based ...
# poster_path                            /sv1xJUazXeYqALzczSZ3O6nkH75.jpg
# backdrop_path                          /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg
# recommendations       436270-829280-76600-56969-312634-1037858-238-5...
#
#                                                                       1  \
# id                                                               315162
# title                                      Puss in Boots: The Last Wish
# genres                                       Animation-Adventure-Comedy
# original_language                                                    en
# overview              Puss in Boots discovers that his passion for a...
# popularity                                                     3351.139
# production_companies            Universal Pictures-DreamWorks Animation
# release_date                                                 2022-12-07
# budget                                                       90000000.0
# revenue                                                     442000000.0
# runtime                                                           103.0
# status                                                         Released
# tagline                                 Say hola to his little friends.
# vote_average                                                      8.461
# vote_count                                                       4047.0
# credits               Antonio Banderas-Salma Hayek-Harvey Guillén-Wa...
# keywords              fairy tale-talking dog-spin off-aftercreditsst...
# poster_path                            /kuf6dutpsT0vSVehic3EZIqkOBt.jpg
# backdrop_path                          /b1Y8SUb12gPHCSSSNlbX4nB3IKy.jpg
# recommendations       536554-76600-816904-653851-899112-985335-83078...
#
#                                                                       2  \
# id                                                               646389
# title                                                             Plane
# genres                                        Action-Adventure-Thriller
# original_language                                                    en
# overview              After a heroic job of successfully landing his...
# popularity                                                     3337.265
# production_companies  Di Bonaventura Pictures-MadRiver Pictures-Rive...
# release_date                                                 2023-01-12
# budget                                                       25000000.0
# revenue                                                      46000000.0
# runtime                                                           107.0
# status                                                         Released
# tagline                                  Survive together or die alone.
# vote_average                                                      6.851
# vote_count                                                        652.0
# credits               Gerard Butler-Mike Colter-Yoson An-Tony Goldwy...
# keywords                           philippines-held hostage-plane crash
# poster_path                            /qi9r5xBgcc9KTxlOLjssEbDgO0J.jpg
# backdrop_path                          /9Rq14Eyrf7Tu1xk0Pl7VcNbNh1n.jpg
# recommendations       937278-536554-653851-615777-9740-593643-555604...
#
#                                                                       3  \
# id                                                               956101
# title                                                 The Eighth Clause
# genres                                                         Thriller
# original_language                                                    la
# overview              Kat and Borja appear to be a perfect couple bu...
# popularity                                                     2259.303
# production_companies                       SDB Films-El Hombre Orquesta
# release_date                                                 2022-04-29
# budget                                                              0.0
# revenue                                                             0.0
# runtime                                                             0.0
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        4.6
# vote_count                                                         10.0
# credits               Maite Perroni-Manuel Vega-Óscar Jaenada-Jessic...
# keywords                                                            NaN
# poster_path                            /8tc8eMFAX2SDC1TRu987qFQy8Cl.jpg
# backdrop_path                          /kLnqNE9Af5QHyvUxw8cDGhF1ilv.jpg
# recommendations                                                     NaN
#
#                                                                       4
# id                                                               536554
# title                                                             M3GAN
# genres                                    Science Fiction-Horror-Comedy
# original_language                                                    en
# overview              A brilliant toy company roboticist uses artifi...
# popularity                                                     1836.162
# production_companies  Universal Pictures-Blumhouse Productions-Atomi...
# release_date                                                 2022-12-28
# budget                                                       12000000.0
# revenue                                                     167643991.0
# runtime                                                           102.0
# status                                                         Released
# tagline                                         Friendship has evolved.
# vote_average                                                       7.51
# vote_count                                                       1794.0
# credits               Allison Williams-Violet McGraw-Jenna Davis-Ami...
# keywords              evil doll-aunt niece relationship-orphan-car a...
# poster_path                            /d9nBoowhjiiYc4FBNtQkPY7c11H.jpg
# backdrop_path                          /j9j7a5rnIKaFiWbuMzC41xgFE4r.jpg
# recommendations       846433-925943-816904-937278-814757-315162-6538...

# %%
#show columns
df.columns
# Out:
# Index(['id', 'title', 'genres', 'original_language', 'overview', 'popularity',
#        'production_companies', 'release_date', 'budget', 'revenue', 'runtime',
#        'status', 'tagline', 'vote_average', 'vote_count', 'credits',
#        'keywords', 'poster_path', 'backdrop_path', 'recommendations'],
#       dtype='object')

# %%
#show shape 
df.shape
# Out:
# (724194, 20)

# %%
#drop unnecessary columns
df = df.drop(['id','recommendations','backdrop_path','status','tagline','keywords', 'credits'], axis=1)

# %%
#show new shape
df.shape
# Out:
# (724194, 13)

# %%
#show the shape when revenue is 0
df[df['revenue'] == 0].shape
# Out:
# (707268, 13)

# %%
#replace 0 with NAN values 
df['revenue'] = df['revenue'].replace(0, np.nan)

# %%
#replace 0 with NAN values
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['budget'] = df['budget'].replace(0, np.nan)

# %%
#show shape where budget is nan
df[df['budget'].isnull()].shape
# Out:
# (687588, 13)

# %%
#add return column that calculates revenue/budget
df['percent_return'] = df['revenue'] / df['budget']

# %%
#show new shape
df[df['percent_return'].isnull()].shape
# Out:
# (713115, 14)

# %%
#replace 0 with NAN values
df['runtime'] = df['runtime'].replace(0, np.nan)

# %%
#drop all remaining null values 
df = df.dropna()

# %%
#show cleaned shape
df.shape
# Out:
# (9472, 14)

# %%
# Look at production_companies value counts for binning
production_counts = df["production_companies"].value_counts()
production_counts.head(40)
# Out:
# Metro-Goldwyn-Mayer                                             128
# Paramount                                                       104
# Warner Bros. Pictures                                           101
# 20th Century Fox                                                 75
# Columbia Pictures                                                60
# Universal Pictures                                               58
# New Line Cinema                                                  40
# RKO Radio Pictures                                               32
# Queens Of Combat                                                 31
# Walt Disney Productions                                          25
# TriStar Pictures                                                 24
# Marvel Studios                                                   24
# Touchstone Pictures                                              24
# Orion Pictures                                                   23
# Yash Raj Films                                                   23
# Bar Wrestling                                                    20
# Walt Disney Pictures-Pixar                                       19
# Imagine Entertainment-Universal Pictures                         18
# DreamWorks Animation                                             18
# Malpaso Productions-Warner Bros. Pictures                        17
# Universal Pictures-Amblin Entertainment                          15
# United Artists                                                   15
# Walt Disney Pictures                                             15
# Walt Disney Pictures-Walt Disney Animation Studios               14
# United Artists-Eon Productions-Danjaq                            14
# Women's Superstars United (WSU)                                  13
# Cannon Group-Golan-Globus Productions                            12
# Walt Disney Pictures-Walt Disney Feature Animation               12
# CT ROAD Entertainment                                            12
# Toho Pictures Inc.                                               11
# ONF | NFB                                                        11
# Miramax                                                          11
# Iranian Independents                                             11
# Warriors Of Wrestling (WOW)                                      10
# German Wrestling Federation                                      10
# 20th Century Fox-Blue Sky Studios-20th Century Fox Animation     10
# Warner Bros. Pictures-Morgan Creek Productions                   10
# Central Partnership                                               9
# World Wonder Ring Stardom                                         9
# Reality Of Wrestling                                              9
# Name: production_companies, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
production_types_to_replace = list(production_counts[production_counts<10].index)

# Replace in dataframe
for prod in production_types_to_replace:
    df['production_companies'] = df['production_companies'].replace(prod,"Other")

# Check to make sure binning was successful
df['production_companies'].value_counts()
# Out:
# Other                                                           8402
# Metro-Goldwyn-Mayer                                              128
# Paramount                                                        104
# Warner Bros. Pictures                                            101
# 20th Century Fox                                                  75
# Columbia Pictures                                                 60
# Universal Pictures                                                58
# New Line Cinema                                                   40
# RKO Radio Pictures                                                32
# Queens Of Combat                                                  31
# Walt Disney Productions                                           25
# Touchstone Pictures                                               24
# Marvel Studios                                                    24
# TriStar Pictures                                                  24
# Orion Pictures                                                    23
# Yash Raj Films                                                    23
# Bar Wrestling                                                     20
# Walt Disney Pictures-Pixar                                        19
# DreamWorks Animation                                              18
# Imagine Entertainment-Universal Pictures                          18
# Malpaso Productions-Warner Bros. Pictures                         17
# Walt Disney Pictures                                              15
# United Artists                                                    15
# Universal Pictures-Amblin Entertainment                           15
# United Artists-Eon Productions-Danjaq                             14
# Walt Disney Pictures-Walt Disney Animation Studios                14
# Women's Superstars United (WSU)                                   13
# Cannon Group-Golan-Globus Productions                             12
# Walt Disney Pictures-Walt Disney Feature Animation                12
# CT ROAD Entertainment                                             12
# Miramax                                                           11
# Toho Pictures Inc.                                                11
# ONF | NFB                                                         11
# Iranian Independents                                              11
# Warriors Of Wrestling (WOW)                                       10
# Warner Bros. Pictures-Morgan Creek Productions                    10
# 20th Century Fox-Blue Sky Studios-20th Century Fox Animation      10
# German Wrestling Federation                                       10
# Name: production_companies, dtype: int64

# %%
df
# Out:
#                                  title                            genres  \
# 0       Black Panther: Wakanda Forever  Action-Adventure-Science Fiction
# 1         Puss in Boots: The Last Wish        Animation-Adventure-Comedy
# 2                                Plane         Action-Adventure-Thriller
# 4                                M3GAN     Science Fiction-Horror-Comedy
# 5                   Knock at the Cabin           Horror-Mystery-Thriller
# ...                                ...                               ...
# 717709                         Requiem                            Comedy
# 719598                         Rejects      Action-Drama-Science Fiction
# 720251               A Brave New World            Science Fiction-Horror
# 720530                      Gal Dil Di                             Music
# 721951           Thiruvalar Panchankam       Drama-Documentary-Animation
#
#        original_language                                           overview  \
# 0                     en  Queen Ramonda Shuri M’Baku Okoye and the Dora ...
# 1                     en  Puss in Boots discovers that his passion for a...
# 2                     en  After a heroic job of successfully landing his...
# 4                     en  A brilliant toy company roboticist uses artifi...
# 5                     en  While vacationing at a remote cabin a young gi...
# ...                  ...                                                ...
# 717709                en  Some neighbors come to the old woman's house a...
# 719598                en  Guns cash and four friends who have the wrong ...
# 720251                ko  A geek is left home alone and his negligence c...
# 720530                pa  Gal Dil Di Directed By -  Parry Sandhu & Harja...
# 721951                en  The film revolves around Karthik (Ananth Nag) ...
#
#         popularity production_companies release_date       budget  \
# 0         3952.862       Marvel Studios   2022-11-09  250000000.0
# 1         3351.139                Other   2022-12-07   90000000.0
# 2         3337.265                Other   2023-01-12   25000000.0
# 4         1836.162                Other   2022-12-28   12000000.0
# 5         1677.354                Other   2023-02-01   20000000.0
# ...            ...                  ...          ...          ...
# 717709       0.600                Other   2018-11-24        500.0
# 719598       0.600                Other   2021-07-30        500.0
# 720251       0.600                Other   2012-04-05    1600000.0
# 720530       0.600                Other   2020-11-03        500.0
# 721951       0.600                Other   2020-12-11          1.0
#
#             revenue  runtime  vote_average  vote_count  \
# 0       855099029.0    162.0         7.403      3586.0
# 1       442000000.0    103.0         8.461      4047.0
# 2        46000000.0    107.0         6.851       652.0
# 4       167643991.0    102.0         7.510      1794.0
# 5        52000000.0    100.0         6.525       546.0
# ...             ...      ...           ...         ...
# 717709        500.0     10.0         0.000         0.0
# 719598        500.0     13.0         8.000         1.0
# 720251     636990.0     41.0         0.000         0.0
# 720530        700.0      4.0         0.000         0.0
# 721951          1.0    113.0         0.000         0.0
#
#                              poster_path     return
# 0       /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   3.420396
# 1       /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   4.911111
# 2       /qi9r5xBgcc9KTxlOLjssEbDgO0J.jpg   1.840000
# 4       /d9nBoowhjiiYc4FBNtQkPY7c11H.jpg  13.970333
# 5       /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2.600000
# ...                                  ...        ...
# 717709  /mvhcwiDeqc9gRvVsm00eWGC9Bqj.jpg   1.000000
# 719598  /d6fRRziWTkgD1xSKWtQkVIozJY6.jpg   1.000000
# 720251  /i8qvcAmJfmcycbEQTVsZP9q2qi6.jpg   0.398119
# 720530  /yeBgOwDlsGrgIMf8j8fsuJjPiLJ.jpg   1.400000
# 721951  /f1mUIuF6rOwHnK2bUJ5WuVZTXGQ.jpg   1.000000
#
# [9472 rows x 14 columns]

# %%
genres_df = df["genres"].str.split("-", expand=True)
genres_df.columns = [f"genre_{i+1}" for i in range(genres_df.shape[1])]

# join the new columns with the original DataFrame
df = pd.concat([df, genres_df], axis=1)

# display the resulting DataFrame
df
# Out:
#                                  title                            genres  \
# 0       Black Panther: Wakanda Forever  Action-Adventure-Science Fiction
# 1         Puss in Boots: The Last Wish        Animation-Adventure-Comedy
# 2                                Plane         Action-Adventure-Thriller
# 4                                M3GAN     Science Fiction-Horror-Comedy
# 5                   Knock at the Cabin           Horror-Mystery-Thriller
# ...                                ...                               ...
# 717709                         Requiem                            Comedy
# 719598                         Rejects      Action-Drama-Science Fiction
# 720251               A Brave New World            Science Fiction-Horror
# 720530                      Gal Dil Di                             Music
# 721951           Thiruvalar Panchankam       Drama-Documentary-Animation
#
#        original_language                                           overview  \
# 0                     en  Queen Ramonda Shuri M’Baku Okoye and the Dora ...
# 1                     en  Puss in Boots discovers that his passion for a...
# 2                     en  After a heroic job of successfully landing his...
# 4                     en  A brilliant toy company roboticist uses artifi...
# 5                     en  While vacationing at a remote cabin a young gi...
# ...                  ...                                                ...
# 717709                en  Some neighbors come to the old woman's house a...
# 719598                en  Guns cash and four friends who have the wrong ...
# 720251                ko  A geek is left home alone and his negligence c...
# 720530                pa  Gal Dil Di Directed By -  Parry Sandhu & Harja...
# 721951                en  The film revolves around Karthik (Ananth Nag) ...
#
#         popularity production_companies release_date       budget  \
# 0         3952.862       Marvel Studios   2022-11-09  250000000.0
# 1         3351.139                Other   2022-12-07   90000000.0
# 2         3337.265                Other   2023-01-12   25000000.0
# 4         1836.162                Other   2022-12-28   12000000.0
# 5         1677.354                Other   2023-02-01   20000000.0
# ...            ...                  ...          ...          ...
# 717709       0.600                Other   2018-11-24        500.0
# 719598       0.600                Other   2021-07-30        500.0
# 720251       0.600                Other   2012-04-05    1600000.0
# 720530       0.600                Other   2020-11-03        500.0
# 721951       0.600                Other   2020-12-11          1.0
#
#             revenue  runtime  ...  vote_count  \
# 0       855099029.0    162.0  ...      3586.0
# 1       442000000.0    103.0  ...      4047.0
# 2        46000000.0    107.0  ...       652.0
# 4       167643991.0    102.0  ...      1794.0
# 5        52000000.0    100.0  ...       546.0
# ...             ...      ...  ...         ...
# 717709        500.0     10.0  ...         0.0
# 719598        500.0     13.0  ...         1.0
# 720251     636990.0     41.0  ...         0.0
# 720530        700.0      4.0  ...         0.0
# 721951          1.0    113.0  ...         0.0
#
#                              poster_path     return          genre_1  \
# 0       /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   3.420396           Action
# 1       /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   4.911111        Animation
# 2       /qi9r5xBgcc9KTxlOLjssEbDgO0J.jpg   1.840000           Action
# 4       /d9nBoowhjiiYc4FBNtQkPY7c11H.jpg  13.970333  Science Fiction
# 5       /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2.600000           Horror
# ...                                  ...        ...              ...
# 717709  /mvhcwiDeqc9gRvVsm00eWGC9Bqj.jpg   1.000000           Comedy
# 719598  /d6fRRziWTkgD1xSKWtQkVIozJY6.jpg   1.000000           Action
# 720251  /i8qvcAmJfmcycbEQTVsZP9q2qi6.jpg   0.398119  Science Fiction
# 720530  /yeBgOwDlsGrgIMf8j8fsuJjPiLJ.jpg   1.400000            Music
# 721951  /f1mUIuF6rOwHnK2bUJ5WuVZTXGQ.jpg   1.000000            Drama
#
#             genre_2          genre_3 genre_4 genre_5 genre_6 genre_7
# 0         Adventure  Science Fiction    None    None    None    None
# 1         Adventure           Comedy    None    None    None    None
# 2         Adventure         Thriller    None    None    None    None
# 4            Horror           Comedy    None    None    None    None
# 5           Mystery         Thriller    None    None    None    None
# ...             ...              ...     ...     ...     ...     ...
# 717709         None             None    None    None    None    None
# 719598        Drama  Science Fiction    None    None    None    None
# 720251       Horror             None    None    None    None    None
# 720530         None             None    None    None    None    None
# 721951  Documentary        Animation    None    None    None    None
#
# [9472 rows x 21 columns]

# %%
clean_df = df.drop(['genre_3','genre_4','genre_5','genre_6','genre_7'], axis=1)

# %%
clean_df = clean_df.drop(['genres'], axis=1)

# %%
clean_df

# %%
clean_df.to_csv('cleaned_movie.csv')

# %% [markdown]
# ## Machine Learning Models

# %%
df['year'] = pd.to_datetime(df['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df['poster_path'] = "<img src='" + base_poster_url + df['poster_path'] + "' style='height:100px;'>"

# %%
df['title'] = df['title'].astype('str')
df['overview'] = df['overview'].astype('str')

# %%
title_corpus = ' '.join(df['title'])
overview_corpus = ' '.join(df['overview'])

# %%
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(title_corpus)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud)
plt.axis('off')
plt.show()

# %%
def clean_numeric(x):
    try:
        return float(x)
    except:
        return np.nan

# %%
df['popularity'] = df['popularity'].apply(clean_numeric).astype('float')
df['vote_count'] = df['vote_count'].apply(clean_numeric).astype('float')
df['vote_average'] = df['vote_average'].apply(clean_numeric).astype('float')

# %%
df['popularity'].describe()
# Out:
# count    9472.000000
# mean       20.868627
# std        79.640242
# min         0.600000
# 25%         5.965000
# 50%        11.893000
# 75%        20.526250
# max      3952.862000
# Name: popularity, dtype: float64

# %%
sns.distplot(df['popularity'].fillna(df['popularity'].median()))
plt.show()

# %%
df['popularity'].plot(logy=True, kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['title', 'popularity', 'year']].sort_values('popularity', ascending=False).head(10)
# Out:
#                                 title  popularity  year
# 0      Black Panther: Wakanda Forever    3952.862  2022
# 1        Puss in Boots: The Last Wish    3351.139  2022
# 2                               Plane    3337.265  2023
# 4                               M3GAN    1836.162  2022
# 5                  Knock at the Cabin    1677.354  2023
# 6                           The Whale    1580.112  2022
# 7   Ant-Man and the Wasp: Quantumania    1545.462  2023
# 11           Avatar: The Way of Water    1287.023  2022
# 14                         Black Adam     924.248  2022
# 17                           Devotion     822.191  2022

# %%
df['vote_count'].describe()
# Out:
# count     9472.000000
# mean      1488.322424
# std       2901.143703
# min          0.000000
# 25%         61.000000
# 50%        387.000000
# 75%       1491.250000
# max      33214.000000
# Name: vote_count, dtype: float64

# %%
df[['title', 'vote_count', 'year']].sort_values('vote_count', ascending=False).head(10)
# Out:
#                         title  vote_count  year
# 710                 Inception     33214.0  2010
# 180              Interstellar     30658.0  2014
# 635           The Dark Knight     29235.0  2008
# 33                     Avatar     28433.0  2009
# 214              The Avengers     28233.0  2012
# 487                  Deadpool     27974.0  2016
# 99     Avengers: Infinity War     26376.0  2018
# 613                Fight Club     25890.0  1999
# 1696  Guardians of the Galaxy     25552.0  2014
# 720              Pulp Fiction     24727.0  1994

# %%
df['vote_average'] = df['vote_average'].replace(0, np.nan)
df['vote_average'].describe()
# Out:
# count    9152.000000
# mean        6.487407
# std         1.089886
# min         0.800000
# 25%         5.900000
# 50%         6.500000
# 75%         7.100000
# max        10.000000
# Name: vote_average, dtype: float64

# %%
sns.distplot(df['vote_average'].fillna(df['vote_average'].median()))
# Out:
# <AxesSubplot:xlabel='vote_average', ylabel='Density'>

# %%
df[df['vote_count'] > 2000][['title', 'vote_average', 'vote_count' ,'year']].sort_values('vote_average', ascending=False).head(10)
# Out:
#                             title  vote_average  vote_count  year
# 383                 The Godfather         8.715     17521.0  1972
# 540      The Shawshank Redemption         8.700     23353.0  1994
# 652         The Godfather Part II         8.597     10604.0  1974
# 818              Schindler's List         8.566     13806.0  1993
# 2409  Dilwale Dulhania Le Jayenge         8.566      4047.0  1995
# 1862                 12 Angry Men         8.535      7067.0  1957
# 498                The Green Mile         8.507     15093.0  1999
# 635               The Dark Knight         8.506     29235.0  2008
# 494                 Spirited Away         8.500     13991.0  2002
# 4414              Cinema Paradiso         8.500      3658.0  1988

# %%
sns.jointplot(x='vote_average', y='popularity', data=df)

# %%
sns.jointplot(x='vote_average', y='vote_count', data=df)

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
day_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
def get_month(x):
    try:
        return month_order[int(str(x).split('-')[1]) - 1]
    except:
        return np.nan

# %%
def get_day(x):
    try:
        year, month, day = (int(i) for i in x.split('-'))    
        answer = datetime.date(year, month, day).weekday()
        return day_order[answer]
    except:
        return np.nan

# %%
df['day'] = df['release_date'].apply(get_day)
df['month'] = df['release_date'].apply(get_month)

# %%
plt.figure(figsize=(12,6))
plt.title("Number of Movies released in a particular month.")
sns.countplot(x='month', data=df, order=month_order)
# Out:
# <AxesSubplot:title={'center':'Number of Movies released in a particular month.'}, xlabel='month', ylabel='count'>

# %%
month_mean = pd.DataFrame(df[df['revenue'] > 1e8].groupby('month')['revenue'].mean())
month_mean['mon'] = month_mean.index
plt.figure(figsize=(12,6))
plt.title("Average Gross by the Month for Blockbuster Movies")
sns.barplot(x='mon', y='revenue', data=month_mean, order=month_order)
# Out:
# <AxesSubplot:title={'center':'Average Gross by the Month for Blockbuster Movies'}, xlabel='mon', ylabel='revenue'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(15, 8))
sns.boxplot(x='month', y='return', data=df[df['return'].notnull()], palette="muted", ax =ax, order=month_order)
ax.set_ylim([0, 12])
# Out:
# (0.0, 12.0)

# %%
plt.figure(figsize=(10,5))
plt.title("Number of Movies released on a particular day.")
sns.countplot(x='day', data=df, order=day_order)
# Out:
# <AxesSubplot:title={'center':'Number of Movies released on a particular day.'}, xlabel='day', ylabel='count'>

# %%
year_count = df.groupby('year')['title'].count()
plt.figure(figsize=(18,5))
year_count.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['year'] != 'NaT'][['title', 'year']].sort_values('year').head(10)
# Out:
#                                                    title  year
# 490688                                Neptune's Daughter  1914
# 401971                            The Rose of the Rancho  1914
# 317137                            The Rose of the Rancho  1914
# 162855                       The Girl of the Golden West  1915
# 131601                                        Temptation  1915
# 9354                               The Birth of a Nation  1915
# 39466                                          The Cheat  1915
# 14898   Intolerance: Love's Struggle Throughout the Ages  1916
# 519385                                        Maria Rosa  1916
# 153554                            A Daughter of the Gods  1916

# %%
months = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# %%
df_21 = df.copy()
df_21['year'] = df_21[df_21['year'] != 'NaT']['year'].astype(int)
df_21 = df_21[df_21['year'] >=2000]
hmap_21 = pd.pivot_table(data=df_21, index='month', columns='year', aggfunc='count', values='title')
hmap_21 = hmap_21.fillna(0)

# %%
sns.set(font_scale=1)
f, ax = plt.subplots(figsize=(16, 8))
sns.heatmap(hmap_21, annot=True, linewidths=.5, ax=ax, fmt='n', yticklabels=month_order)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.set(font_scale=1.25)

# %%
df['runtime'].describe()
# Out:
# count    9472.000000
# mean      106.420925
# std        28.347991
# min         1.000000
# 25%        93.000000
# 50%       104.000000
# 75%       120.000000
# max       480.000000
# Name: runtime, dtype: float64

# %%
df['runtime'] = df['runtime'].astype('float')

# %%
plt.figure(figsize=(12,6))
sns.distplot(df[(df['runtime'] < 300) & (df['runtime'] > 0)]['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Density'>

# %%
df_mat = df[(df['return'].notnull()) & (df['runtime'] > 0) & (df['return'] < 10)]
sns.jointplot('return', 'runtime', data=df_mat)
plt.show()

# %%
df_mat = df[(df['budget'].notnull()) & (df['runtime'] > 0)]
sns.jointplot('budget', 'runtime', data=df_mat)
plt.show()

# %%
plt.figure(figsize=(18,5))
year_runtime = df[df['year'] != 'NaT'].groupby('year')['runtime'].mean()
plt.plot(year_runtime.index, year_runtime)
plt.xticks(np.arange(1874, 2024, 10.0))
plt.show()

# %%
df[df['runtime'] > 0][['runtime', 'title', 'year']].sort_values('runtime').head(10)
# Out:
#         runtime                                             title  year
# 253573      1.0                                  The Dirt on Soap  2000
# 195717      1.0                          How to Water a Sunflower  2019
# 521794      1.0            Science Please! : Wheel Meets Friction  1998
# 546319      1.0  Science Please! : The Internal Combustion Engine  2000
# 569616      1.0                                             Homer  2019
# 543107      1.0                                      Chromosaurus  1985
# 378240      1.0                                         Hostility  2015
# 542315      1.0                                         Big Smoke  1993
# 556364      1.0                                              Fire  2001
# 652077      1.0                               Death of a Criminal  2014

# %%
df[df['runtime'] > 0][['runtime', 'title', 'year']].sort_values('runtime', ascending=False).head(10)
# Out:
#         runtime                                           title  year
# 704193    480.0                       2019: A Cinematic Odyssey  2019
# 106879    279.0  Eric Clapton's Crossroads Guitar Festival 2010  2010
# 10609     254.0                                      Gettysburg  1993
# 3437      248.0                                       Cleopatra  1963
# 268       242.0                    Zack Snyder's Justice League  2021
# 3229      238.0                              Gone with the Wind  1939
# 2207      229.0                     Once Upon a Time in America  1984
# 2823      228.0                              Lawrence of Arabia  1962
# 24418     225.0                                       Woodstock  1970
# 9565      224.0               Lagaan: Once Upon a Time in India  2001

# %%
df['budget'].describe()
# Out:
# count    9.472000e+03
# mean     2.374674e+07
# std      3.762023e+07
# min      1.000000e+00
# 25%      2.000000e+06
# 50%      1.000000e+07
# 75%      2.800000e+07
# max      4.600000e+08
# Name: budget, dtype: float64

# %%
sns.distplot(df[df['budget'].notnull()]['budget'])
# Out:
# <AxesSubplot:xlabel='budget', ylabel='Density'>

# %%
df['budget'].plot(logy=True, kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df['budget'].notnull()][['title', 'budget', 'revenue', 'return', 'year']].sort_values('budget', ascending=False).head(10)
# Out:
#                                              title       budget       revenue  \
# 11                        Avatar: The Way of Water  460000000.0  2.267384e+09
# 356    Pirates of the Caribbean: On Stranger Tides  380000000.0  1.045714e+09
# 330                        Avengers: Age of Ultron  365000000.0  1.405404e+09
# 250                              Avengers: Endgame  356000000.0  2.799439e+09
# 99                          Avengers: Infinity War  300000000.0  2.046240e+09
# 47995                 Mega Man X: The Day of Sigma  300000000.0  4.280000e+08
# 740                                 Justice League  300000000.0  6.579270e+08
# 366       Pirates of the Caribbean: At World's End  300000000.0  9.610000e+08
# 2692                              Superman Returns  270000000.0  3.910812e+08
# 215                                        Tangled  260000000.0  5.924617e+08
#
#          return  year
# 11     4.929095  2022
# 356    2.751878  2011
# 330    3.850421  2015
# 250    7.863593  2019
# 99     6.820799  2018
# 47995  1.426667  2005
# 740    2.193090  2017
# 366    3.203333  2007
# 2692   1.448449  2006
# 215    2.278699  2010

# %%
sns.jointplot(x='budget',y='revenue',data=df[df['return'].notnull()])

# %%
df['revenue'].describe()
# Out:
# count    9.472000e+03
# mean     6.754679e+07
# std      1.571883e+08
# min      1.000000e+00
# 25%      1.829103e+06
# 50%      1.350000e+07
# 75%      6.066656e+07
# max      2.920357e+09
# Name: revenue, dtype: float64

# %%
sns.distplot(df[df['revenue'].notnull()]['revenue'])
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='Density'>

# %%
gross_top = df[['poster_path', 'title', 'budget', 'revenue', 'year']].sort_values('revenue', ascending=False).head(10)
pd.set_option('display.max_colwidth', 100)
HTML(gross_top.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>budget</th>
#       <th>revenue</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>33</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg' style='height:100px;'></td>
#       <td>Avatar</td>
#       <td>237000000.0</td>
#       <td>2.920357e+09</td>
#       <td>2009</td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//or06FN3Dka5tukK1e9sl16pB3iy.jpg' style='height:100px;'></td>
#       <td>Avengers: Endgame</td>
#       <td>356000000.0</td>
#       <td>2.799439e+09</td>
#       <td>2019</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//t6HIqrRAclMCA60NsSmeqe9RmNV.jpg' style='height:100px;'></td>
#       <td>Avatar: The Way of Water</td>
#       <td>460000000.0</td>
#       <td>2.267384e+09</td>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>Titanic</td>
#       <td>200000000.0</td>
#       <td>2.187464e+09</td>
#       <td>1997</td>
#     </tr>
#     <tr>
#       <th>1130</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg' style='height:100px;'></td>
#       <td>Star Wars: The Force Awakens</td>
#       <td>245000000.0</td>
#       <td>2.068224e+09</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7WsyChQLEftFiDOVTGkv3hFpyyt.jpg' style='height:100px;'></td>
#       <td>Avengers: Infinity War</td>
#       <td>300000000.0</td>
#       <td>2.046240e+09</td>
#       <td>2018</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uJYYizSuA9Y3DCs0qS4qWvHfZg4.jpg' style='height:100px;'></td>
#       <td>Spider-Man: No Way Home</td>
#       <td>200000000.0</td>
#       <td>1.921847e+09</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>467</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//A0LZHXUzo5C60Oahvt7VxvwuzHw.jpg' style='height:100px;'></td>
#       <td>Jurassic World</td>
#       <td>150000000.0</td>
#       <td>1.671537e+09</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>521</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dzBtMocZuJbjLOXvrl4zGYigDzh.jpg' style='height:100px;'></td>
#       <td>The Lion King</td>
#       <td>260000000.0</td>
#       <td>1.663075e+09</td>
#       <td>2019</td>
#     </tr>
#     <tr>
#       <th>214</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>The Avengers</td>
#       <td>220000000.0</td>
#       <td>1.518816e+09</td>
#       <td>2012</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.set_option('display.max_colwidth', 50)

# %%
plt.figure(figsize=(18,5))
year_revenue = df[(df['revenue'].notnull()) & (df['year'] != 'NaT')].groupby('year')['revenue'].max()
plt.plot(year_revenue.index, year_revenue)
plt.show()

# %%
df[(df['return'].notnull()) & (df['budget'] > 5e6)][['title', 'budget', 'revenue', 'return', 'year']].sort_values('return', ascending=False).head(10)
# Out:
#                             title      budget      revenue     return  year
# 2278   E.T. the Extra-Terrestrial  10500000.0  792965500.0  75.520524  1982
# 524                     Star Wars  11000000.0  775398007.0  70.490728  1977
# 1864                         Jaws   7000000.0  470653000.0  67.236143  1975
# 12318            Jab Tak Hai Jaan   6087315.0  256884693.0  42.200000  2012
# 383                 The Godfather   6000000.0  245066411.0  40.844402  1972
# 11128          Look Who's Talking   7500000.0  296999813.0  39.599975  1989
# 1619                    Annabelle   6500000.0  257047661.0  39.545794  2014
# 4455                       Ne Zha  20000000.0  742500000.0  37.125000  2019
# 14412             Fahrenheit 9/11   6000000.0  222446882.0  37.074480  2004
# 3770                Dirty Dancing   6000000.0  214577242.0  35.762874  1987

# %%
df[(df['return'].notnull()) & (df['budget'] > 5e6) & (df['revenue'] > 10000)][['title', 'budget', 'revenue', 'return', 'year']].sort_values('return').head(10)
# Out:
#                                                     title       budget  \
# 850                                           White Noise  100000000.0
# 16097                                     Accidental Love   26000000.0
# 441                                            Red Notice  160000000.0
# 15691                                          Foodfight!   65000000.0
# 2374                                       Space Sweepers   21000000.0
# 60507                                       Ripple Effect   12000000.0
# 124190  The Tulse Luper Suitcases, Part 3: From Sark t...   10000000.0
# 7583                                            Term Life   16500000.0
# 16568                                         Cherry 2000   10000000.0
# 22069                                          Twice Born   13000000.0
#
#          revenue    return  year
# 850      71476.0  0.000715  2022
# 16097    24487.0  0.000942  2015
# 441     178143.0  0.001113  2021
# 15691    73706.0  0.001134  2012
# 2374     24571.0  0.001170  2021
# 60507    14059.0  0.001172  2007
# 124190   12000.0  0.001200  2004
# 7583     21256.0  0.001288  2016
# 16568    14000.0  0.001400  1987
# 22069    18295.0  0.001407  2012

# %%
df['year'] = df['year'].replace('NaT', np.nan)

# %%
df['year'] = df['year'].apply(clean_numeric)

# %%
sns.set(font_scale=1)
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    plt.figure(figsize=(9,9))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True)

# %%
sns.set(font_scale=1.25)
